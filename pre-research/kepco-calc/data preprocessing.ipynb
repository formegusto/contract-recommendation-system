# %%
import pandas as pd
import numpy as np
import datetime as dt
import math as mt
import datetime as dt

# %% [markdown]
# # Data Processing Process
# ---
# 1. Read Data (pd.read_excel, plain data)
# 2. Convert DataFrame Type
# 3. peak DataFrame
# 4. month usage DataFrame

# %% [markdown]
# # Read Data

# %%
xlsx = pd.read_excel("datas/datas.xlsx", header=None, skiprows=2, engine="openpyxl")

# %% [markdown]
# # Convert DataFrame Type

# %%
# column [7] row [0] - Household Name (아파트명)
# column [7] row [1] - Household Name (동)
# column [7] row [2] - Household Name (호수)
# column [7] row[3] - Start kWh Data 

# column [0] row [3] - YYYYMMDD
# column [1] row [3] - YYYY
# column [2] row [3] - MM
# column [3] row [3] - DD
# column [4] row [3] - hh
# column [5] row [3] - mm

# household list
# dt.datetime(xlsx[1][3], xlsx[2][3], xlsx[3][3], xlsx[4][3], xlsx[5][4])
date_df = xlsx[3:][xlsx.columns[1:6]].copy()
household_df = xlsx[xlsx.columns[7:]]

date_list = [dt.datetime(
    date_df.loc[_][1],
    date_df.loc[_][2],
    date_df.loc[_][3],
    date_df.loc[_][4],
    date_df.loc[_][5]
) for _ in date_df.index]

datas_df = pd.DataFrame(columns=['date'])
datas_df['date'] = date_list

for col in household_df:
    household_name = "{}-{}-{}".format(
        household_df[col][0],
        household_df[col][1],
        household_df[col][2]
    )
    datas_df[household_name] = household_df[col][3:].to_list()
    
datas_df = datas_df.replace("-", 0)
datas_df
# Out:
#                      date  아파트1-104-1206  아파트1-104-303  아파트1-104-1307  \
# 0     2018-05-01 00:00:00          0.085         0.016          0.052
# 1     2018-05-01 00:15:00          0.086         0.049          0.053
# 2     2018-05-01 00:30:00          0.085         0.013          0.073
# 3     2018-05-01 00:45:00          0.085         0.043          0.067
# 4     2018-05-01 01:00:00          0.084         0.033          0.051
# ...                   ...            ...           ...            ...
# 35035 2019-04-30 22:45:00          0.007         0.027          0.011
# 35036 2019-04-30 23:00:00          0.006         0.022          0.014
# 35037 2019-04-30 23:15:00          0.015         0.024          0.009
# 35038 2019-04-30 23:30:00          0.023         0.023          0.016
# 35039 2019-04-30 23:45:00          0.014         0.033          0.009
#
#        아파트1-104-1208  아파트1-104-408  아파트1-104-203  아파트1-103-1402  아파트1-103-402  \
# 0              0.003         0.032         0.074          0.053         0.096
# 1              0.002         0.022         0.014          0.048         0.090
# 2              0.002         0.016         0.051          0.029         0.033
# 3              0.002         0.015         0.015          0.031         0.092
# 4              0.003         0.022         0.052          0.052         0.030
# ...              ...           ...           ...            ...           ...
# 35035          0.066         0.014         0.066          0.066         0.080
# 35036          0.063         0.030         0.061          0.063         0.215
# 35037          0.062         0.030         0.064          0.060         0.164
# 35038          0.063         0.029         0.063          0.038         0.132
# 35039          0.053         0.025         0.060          0.049         0.187
#
#        아파트1-103-1201  ...  아파트4-105-102  아파트4-103-1102  아파트4-105-601  \
# 0              0.105  ...         0.182          0.044         0.051
# 1              0.108  ...         0.117          0.060         0.036
# 2              0.097  ...         0.147          0.053         0.075
# 3              0.048  ...         0.152          0.047         0.064
# 4              0.041  ...         0.110          0.042         0.036
# ...              ...  ...           ...            ...           ...
# 35035          0.016  ...         0.119          0.087         0.029
# 35036          0.033  ...         0.148          0.089         0.070
# 35037          0.051  ...         0.112          0.070         0.039
# 35038          0.046  ...         0.147          0.084         0.044
# 35039          0.044  ...         0.101          0.067         0.067
#
#        아파트4-104-1501  아파트4-103-702  아파트4-102-104  아파트4-103-902  아파트4-101-602  \
# 0              0.057         0.126         0.094         0.065         0.116
# 1              0.055         0.116         0.089         0.083         0.113
# 2              0.032         0.131         0.055         0.084         0.153
# 3              0.022         0.104         0.057         0.087         0.149
# 4              0.035         0.104         0.062         0.087         0.130
# ...              ...           ...           ...           ...           ...
# 35035          0.098         0.075         0.023         0.238         0.363
# 35036          0.090         0.086         0.026         0.242         0.354
# 35037          0.098         0.113         0.037         0.193         0.309
# 35038          0.099         0.071         0.050         0.156         0.259
# 35039          0.038         0.110         0.025         0.128         0.253
#
#        아파트4-103-905  아파트4-101-104
# 0             0.093         0.147
# 1             0.105         0.130
# 2             0.119         0.104
# 3             0.102         0.093
# 4             0.083         0.093
# ...             ...           ...
# 35035         0.057         0.132
# 35036         0.078         0.122
# 35037         0.041         0.121
# 35038         0.070         0.106
# 35039         0.069         0.109
#
# [35040 rows x 399 columns]

# %% [markdown]
# # peak DataFrame

# %%
sum_df = pd.DataFrame(columns=['date', 'kWh', 'kW'])
sum_df['date'] = date_list
sum_df['kWh'] = datas_df[datas_df.columns.difference(['date'])].sum(axis=1).to_list()
sum_df['kW'] = (sum_df['kWh'] / 0.25).to_list()

sum_df
# Out:
#                      date     kWh       kW
# 0     2018-05-01 00:00:00  24.078   96.312
# 1     2018-05-01 00:15:00  23.787   95.148
# 2     2018-05-01 00:30:00  23.510   94.040
# 3     2018-05-01 00:45:00  21.312   85.248
# 4     2018-05-01 01:00:00  20.642   82.568
# ...                   ...     ...      ...
# 35035 2019-04-30 22:45:00  41.335  165.340
# 35036 2019-04-30 23:00:00  40.346  161.384
# 35037 2019-04-30 23:15:00  40.572  162.288
# 35038 2019-04-30 23:30:00  39.064  156.256
# 35039 2019-04-30 23:45:00  38.083  152.332
#
# [35040 rows x 3 columns]

# %%
peak_df = pd.DataFrame(columns=['month', 'kW'])

for month in range(1,13):
    peak_df = peak_df.append({
        "month": str(month),
        "kW": sum_df[sum_df['date'].dt.month == month]['kW'].max()
    }, ignore_index=True)
    
peak_df
# Out:
#    month       kW
# 0      1  222.088
# 1      2  222.060
# 2      3  211.240
# 3      4  209.432
# 4      5  153.824
# 5      6  200.812
# 6      7  356.536
# 7      8  354.004
# 8      9  202.160
# 9     10  193.708
# 10    11  213.440
# 11    12  221.292

# %% [markdown]
# # month usage DataFrame

# %%
month_usage_df = pd.DataFrame(columns=['month'])
month_usage_df['month'] = [_ for _ in range(1,13)]

for name in datas_df[datas_df.columns.difference(['date'])]:
    self_household_df = datas_df[['date',name]].copy()
    
    month_usage_df[name] = [
        self_household_df[self_household_df['date'].dt.month == month][name].sum()
        for month in range(1,13)
    ]

# %%
month_usage_df
